# %% [markdown]
# # Using BERT to Identify Bill Hardy (Binary Classification of Sentences) [WIP]

# %% [markdown]
# Now that K-means clustering seems to indicate that some of the narrators can be inferred from the pages, we can attempt to use a language model to predict whether a sentence belongs to a given narrator.
#
# Let's start with a binary classification to **predict if sentences belong or not to Bill Hardy**.
#
# <img src="https://glthr.com/cj/characters/bill-min.jpg" alt="drawing" width="400"/>

# %%
# %%capture

# make logs less verbose
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# suppress UnparsedFlagAccessError warning
import sys
from absl import flags

sys.argv = ["preserve_unused_tokens=False"]
flags.FLAGS(sys.argv)

# suppress Pandas Future Warning (deprecation of DataFrame.swapaxes)
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## Process data

# %%
import pandas as pd

df = pd.read_json("./data/jawbone.json")

# %% [markdown]
# Augment the data with the label: `True` for Bill Hardy, `False` otherwise.

# %%
import json

f = open("./data/unofficial_solution.json")
possible_solutions = json.load(f)
f.close()


def is_bill(id):
    for key, ids in possible_solutions.items():
        if id in ids:
            return key == "Bill Hardy"
    return None


df = df.astype({"text": "string"})
df["narrator"] = df["page"].apply(lambda x: is_bill(x))
df
# Out:
#     page                                               text  narrator
# 0      1  I sit down alone at the appointed table and ta...      True
# 1      2  I plunged for the last time. The few remaining...     False
# 2      3  At my meeting with Clement yesterday, he had b...     False
# 3      4  And I really think I would have preferred the ...      True
# 4      5  I hated my eye for being caught by what didn’t...     False
# ..   ...                                                ...       ...
# 95    96  Now I think I will try a cup of what they inso...      True
# 96    97  To have slept and to wake right up surrounded ...     False
# 97    98  He stood and looked down at me; but I was not ...     False
# 98    99  And she wore a mauve love-knot on her breast, ...     False
# 99   100  I dimly guess why the old dead so wanted this....      True
#
# [100 rows x 3 columns]

# %%
# tokenize pages
import nltk
from nltk import sent_tokenize


def tokenize_sentences(paragraph):
    sentences = sent_tokenize(paragraph)

    valid_sentences = [
        sentence for sentence in sentences if any(c.isalnum() for c in sentence)
    ]
    return valid_sentences


df["text"] = df["text"].apply(tokenize_sentences)
df = df.explode("text").reset_index(drop=True)
df
# Out:
#       page                                               text  narrator
# 0        1  I sit down alone at the appointed table and ta...      True
# 1        1  Call me nervous, call me fey, if you will; at ...      True
# 2        1  It has not had much work since it flew so nimb...      True
# 3        1  As I watch the sea, Casy Ferris passes with do...      True
# 4        1                      Of course, to-day is the day.      True
# ...    ...                                                ...       ...
# 1225   100                                   O beastly woman.      True
# 1226   100  You know not how ill’s all here, about my hear...      True
# 1227   100  Henry, I feel it, is for the first and last ti...      True
# 1228   100                                   Good-bye, Henry.      True
# 1229   100                                      He drops awa.      True
#
# [1230 rows x 3 columns]

# %% [markdown]
# ## Train BERT Model

# %%
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from transformers import logging

logging.set_verbosity_error()  # suppress untrained weight error (unconsequential)

# use BERT large uncased model
# https://huggingface.co/bert-large-uncased
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=1)

# %%
from sklearn.model_selection import train_test_split

# sample 25% of the book and ensure that at least 1/4 for the sentences are related
# to Bill Hardy
sample_size = 0.25
bill_count = 0
while bill_count < (sample_size * 100) / 4:
    df_sampled = df.sample(frac=0.25)
    values_count = df_sampled["narrator"].value_counts()
    bill_count = 0 if not True in values_count else values_count[True]

# split datasets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    df_sampled["text"].values,
    df_sampled["narrator"].values,
    test_size=0.2,
    random_state=42,
)

print(f"Train dataset size: {train_texts.shape[0]}")
print(f"Test dataset size: {test_texts.shape[0]}")
# Out:
# Train dataset size: 246
# Test dataset size: 62

# %%
from torch.utils.data import DataLoader, Dataset


# tokenize and prepare the input data
class TokenizedData(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = float(self.labels[idx])
        inputs = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt",
        )
        return {
            "input_ids": inputs["input_ids"].flatten(),
            "attention_mask": inputs["attention_mask"].flatten(),
            "label": torch.tensor(label, dtype=torch.float32),
        }


train_dataloader = DataLoader(
    TokenizedData(train_texts, train_labels, tokenizer), batch_size=20, shuffle=True
)
val_dataloader = DataLoader(
    TokenizedData(test_texts, test_labels, tokenizer), batch_size=20, shuffle=False
)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
optimizer = AdamW(model.parameters(), lr=2e-5)
criterion = torch.nn.BCEWithLogitsLoss()

num_epochs = 20
model.to(device)

for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0

    for batch in train_dataloader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].squeeze().to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask)

        # loss computation
        loss = criterion(outputs.logits.flatten(), labels)
        loss.backward()

        # parameters update
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_dataloader)
    print(f"{epoch + 1}/{num_epochs} — loss: {avg_loss:.4f}")
# Out:
# 1/20 — loss: 0.5954
# 2/20 — loss: 0.4685
# 3/20 — loss: 0.3944
# 4/20 — loss: 0.2839
# 5/20 — loss: 0.1943
# 6/20 — loss: 0.1048
# 7/20 — loss: 0.0633
# 8/20 — loss: 0.0435
# 9/20 — loss: 0.0170
# 10/20 — loss: 0.0103
# 11/20 — loss: 0.0070
# 12/20 — loss: 0.0055
# 13/20 — loss: 0.0047
# 14/20 — loss: 0.0039
# 15/20 — loss: 0.0035
# 16/20 — loss: 0.0032
# 17/20 — loss: 0.0029
# 18/20 — loss: 0.0026
# 19/20 — loss: 0.0024
# 20/20 — loss: 0.0021

# %%
from sklearn.metrics import accuracy_score

model.eval()
predictions = []
true_labels = []

with torch.no_grad():
    for batch in val_dataloader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["label"].numpy()

        outputs = model(input_ids, attention_mask=attention_mask)
        predictions.extend(outputs.logits.flatten().cpu().numpy())
        true_labels.extend(labels)

predictions = [1 if p > 0.5 else 0 for p in predictions]
accuracy = accuracy_score(true_labels, predictions)

print(f"Validation accuracy: {accuracy:.4f}")
# Out:
# Validation accuracy: 0.9194

# %% [markdown]
# ## Predict

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification


model.eval()

inputs = tokenizer(
    [text for text in df.text.values],
    return_tensors="pt",
    truncation=True,
    padding=True,
)
input_ids = inputs["input_ids"].to(device)
attention_mask = inputs["attention_mask"].to(device)

with torch.no_grad():
    outputs = model(input_ids, attention_mask=attention_mask)

probabilities = torch.sigmoid(outputs.logits).cpu().numpy()
predicted_labels = (probabilities > 0.5).astype(int)

# %% [markdown]
# Confusion matrix

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(df.narrator.values, predicted_labels)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm, display_labels=["Not Bill Hardy", "Bill Hardy"]
)

plt.figure(figsize=(8, 6))
disp.plot(cmap="Blues")

plt.show()

# %% [markdown]
# Identify misclassified sentences

# %%
misclassified_indices = [
    i
    for i, (true, pred) in enumerate(zip(df.narrator.values, predicted_labels))
    if true != pred
]

print("Misclassified Sentences:")
for index in misclassified_indices:
    print(
        f"True Label: {int(df.narrator.values[index])} — predicted Label: {predicted_labels[index][0]} — text: {df.text.values[index]}"
    )
    print()
# Out:
# Misclassified Sentences:
# True Label: 0 — predicted Label: 1 — text: No friend of mine takes his ease in my chair.
#
# True Label: 1 — predicted Label: 0 — text: But the queen can do no wrong.
#
# True Label: 1 — predicted Label: 0 — text: Can I suspect her?
#
# True Label: 0 — predicted Label: 1 — text: Why not?
#
# True Label: 0 — predicted Label: 1 — text:     Rintrah, where has thou hid thy bride?
#
# True Label: 0 — predicted Label: 1 — text: Weeps she in desert shades?
#
# True Label: 0 — predicted Label: 1 — text: Alas!
#
# True Label: 1 — predicted Label: 0 — text: Conveniently situated for some things, that is.
#
# True Label: 1 — predicted Label: 0 — text: I’ve never tried the stuff myself; bad for the hand.
#
# True Label: 1 — predicted Label: 0 — text: Or the Moning, very choice, delicate flavour.
#
# True Label: 1 — predicted Label: 0 — text: Why go to pubs?
#
# True Label: 1 — predicted Label: 0 — text: There would be no Moning at the bar.
#
# True Label: 1 — predicted Label: 0 — text: Because, perhaps, marriage is in the air?
#
# True Label: 0 — predicted Label: 1 — text: It is somewhat too sensational.
#
# True Label: 0 — predicted Label: 1 — text: I feel rather frightened.
#
# True Label: 0 — predicted Label: 1 — text: We have circled and circled till we have arrived home again, we two.
#
# True Label: 1 — predicted Label: 0 — text: Bill to Solve the Traffic Problem.
#
# True Label: 1 — predicted Label: 0 — text: Bill to improve the Secondary Schools.
#
# True Label: 1 — predicted Label: 0 — text: Pure Francis Thompson.
#
# True Label: 1 — predicted Label: 0 — text: He sold matches.
#
# True Label: 0 — predicted Label: 1 — text: No, Sir; it is not a very interesting subject.
#
# True Label: 1 — predicted Label: 0 — text: Your gardenia is difficult at a distance to determine.
#
# True Label: 0 — predicted Label: 1 — text: Caseus, ah!
#
# True Label: 0 — predicted Label: 1 — text: Henceforth I whimper no more, postpone no more, need nothing, done with indoor complaints, libraries, querulous criticisms.
#
# True Label: 0 — predicted Label: 1 — text: If he who so tragically killed his King, ever reached here at all, which is historically more than doubtful (alas, poor Richard!
#
# True Label: 0 — predicted Label: 1 — text: Alas, poor Thomas!)
#
# True Label: 0 — predicted Label: 1 — text: Poor Sonia Gordon.
#
# True Label: 0 — predicted Label: 1 — text: What chemistry!
#
# True Label: 0 — predicted Label: 1 — text: And some to Flecker turn to pray, and I toward thy bed.
#
# True Label: 0 — predicted Label: 1 — text: The bean bursts noiselessly through the mould in the garden.
#
# True Label: 0 — predicted Label: 1 — text: Out of its little hill faithfully rise the potato’s dark green leaves.
#
# True Label: 0 — predicted Label: 1 — text: Poor lonely little Bat.
#
# True Label: 0 — predicted Label: 1 — text: Julienne?
#
# True Label: 1 — predicted Label: 0 — text: Is there some esoteric meaning behind the titles?
#
# True Label: 1 — predicted Label: 0 — text: They ca’d me Ecky when I was a boy.
#
# True Label: 1 — predicted Label: 0 — text: Emotional stuff.
#
# True Label: 1 — predicted Label: 0 — text: Where would my income be if Aquarius were to turn Gemini?
#
# True Label: 1 — predicted Label: 0 — text: A greyness and a spray to begin with, and suddenly a birth of little silver frogs all along the road.
#
# True Label: 1 — predicted Label: 0 — text: We were sitting in the verandah in the dead, hot, close air, gasping and praying that the black-blue clouds would let down and bring the cool.
#
# True Label: 1 — predicted Label: 0 — text: I always think of that, even in England.
#
# True Label: 0 — predicted Label: 1 — text: It is a marvellous gift, I always think.
#
# True Label: 0 — predicted Label: 1 — text: I dance with the dancers and drink with the drinkers.
#
# True Label: 0 — predicted Label: 1 — text: Death closes all: but something ere the end, some work of noble note, may yet be done.
#
# True Label: 1 — predicted Label: 0 — text: I have always hated that these writers should be anonymous.
#
# True Label: 1 — predicted Label: 0 — text: But I have called them all by their names.
#
# True Label: 0 — predicted Label: 1 — text: That is their tragedy.
#
# True Label: 0 — predicted Label: 1 — text: No man does.
#
# True Label: 0 — predicted Label: 1 — text: I must—oh, final and most difficult hobby!—collect myself.
#
# True Label: 0 — predicted Label: 1 — text: O the orator’s joys!
#
# True Label: 0 — predicted Label: 1 — text: O triste, triste était mon âme, to inflate the chest, to roll the thunder of the voice out from the ribs and throat à cause, à cause d’une femme.
#
# True Label: 0 — predicted Label: 1 — text: I am not incautious.
#
# True Label: 0 — predicted Label: 1 — text: Oh, yeah.
#
# True Label: 0 — predicted Label: 1 — text: Band, Speckled.
#
# True Label: 0 — predicted Label: 1 — text: I must learn Spanish one of these days, only for that slow sweet name’s sake.
#
# True Label: 1 — predicted Label: 0 — text: Off went his arm to-day.
#
# True Label: 1 — predicted Label: 0 — text: Yes, what would I feel like?
#
# True Label: 0 — predicted Label: 1 — text: The murderer that is to be hung next day, how does he sleep?
#
# True Label: 0 — predicted Label: 1 — text: What a man!
#
# True Label: 0 — predicted Label: 1 — text: Why should that stick in my head?
#
# True Label: 0 — predicted Label: 1 — text: I hasten to inform him or her it is just as lucky to die, and I know it.
#
# True Label: 0 — predicted Label: 1 — text: Perish the thought, and the fellow.
#
# True Label: 1 — predicted Label: 0 — text: I have given her nothing at all.
#
# True Label: 1 — predicted Label: 0 — text: Not that it can really be skeleton yet; it must be—worse: a loathsome mass of detestable putrescence.
#
# True Label: 0 — predicted Label: 1 — text: You will, Oscar, you will.
#
# True Label: 0 — predicted Label: 1 — text: Yet now my heart leaps, O beloved!
#
# True Label: 0 — predicted Label: 1 — text: God’s child with his dew    On they gracious gold hair, and those lilies still        living and blue
#
# True Label: 0 — predicted Label: 1 — text: And pipes for closets all over, and cutting the framestoo light,But M’Cullough he died in the sixties, and—well,I’m dying to-night .
#
# True Label: 1 — predicted Label: 0 — text: Is it at all like the Plover’s Lunch, that hurts and is desired?
#
# True Label: 1 — predicted Label: 0 — text: The whole business reminds me of the time we lay outside Jifjaffa, and the Padre said to me: “I would rather have written that poem than take castor oil in the morning.” I had been reading him my Ode on the Intimations of Immorality in Early Childhood.
#
# True Label: 0 — predicted Label: 1 — text: Ouvre ton âme et ton oreille au son de ma mandoline: pour toi j’ai fait, pour toi, cette chanson cruelle et caline.
#
# True Label: 0 — predicted Label: 1 — text: Gone, in a relative sense alas!
#
# True Label: 1 — predicted Label: 0 — text: I had worked for him, Henry had worked for him.
#
# True Label: 1 — predicted Label: 0 — text: Scotland Yard, of course.
